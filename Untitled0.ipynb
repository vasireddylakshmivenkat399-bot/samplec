# %% [markdown]
# <a href="https://colab.research.google.com/github/vasireddylakshmivenkat399-bot/samplec/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World2")
# Out:
# Hello World2

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>
